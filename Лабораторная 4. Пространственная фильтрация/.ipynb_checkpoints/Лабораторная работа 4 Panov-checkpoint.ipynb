# %% [markdown]
# # Лабораторная 4. Пространственная фильтрация

# %% [markdown]
# Выполнить улучшение изображения по описанию (Гонсалес п.3.8 или 3.7 (зависит от года издания), кратко в презентации)

# %%
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline 
import numpy as np
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %% [markdown]
# # Функция вывода изображения

# %%
def showImage(images, size = 10, colorMap = 'gray'):
    countImages = len(images)
    #size *= countImages
    pic_box = plt.figure(figsize=(size, size * countImages))
    for i, image in enumerate(images):
        pic_box.add_subplot(countImages, 2, i+1)
        plt.imshow(image)
        plt.set_cmap(colorMap)
        plt.axis('off')
    plt.show()

# %%
imageSrs = cv2.imread("1.jpg")

showImage([imageSrs, imageSrs, imageSrs, imageSrs, imageSrs, imageSrs, imageSrs, imageSrs])

# %%
print(cv2.CV_64F)
# Out:
# 6

# %%
grayImage = cv2.cvtColor(imageSrs, cv2.COLOR_BGR2GRAY)
laplacian = cv2.Laplacian(grayImage, cv2.CV_64F)
showImage(laplacian)
