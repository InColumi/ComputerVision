# %%
from io import BytesIO
from skimage import io
from PIL import Image, ImageDraw
from skimage import img_as_float
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline 
import math

# %% [markdown]
# # Функция вывода изображения

# %%
def showImage(images, size = 15, colorMap = 'gray'):
    countImages = len(images)
    #size *= countImages
    pic_box = plt.figure(figsize=(size, size * countImages))
    for i, image in enumerate(images):
        pic_box.add_subplot(countImages, 2, i+1)
        plt.imshow(image)
        plt.set_cmap(colorMap)
        plt.subplots_adjust(wspace=0, hspace=0.1)
        plt.axis('off')
    plt.show()

# %% [markdown]
# # Функция сдвига

# %%
def get_fftshift(image: np.ndarray):
    image_dft = cv2.dft(np.float32(image), flags = cv2.DFT_COMPLEX_OUTPUT)
    return np.fft.fftshift(image_dft)

# %% [markdown]
# # Функция для спектра изображения

# %%
def get_spectrum(image: np.ndarray):
    dft_shift = get_fftshift(image)
    magnitude = cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1])
    return np.log(magnitude)

# %% [markdown]
# # Функция нахождения расстояния между точками

# %%
def get_distance(a, b, c, d):
    return math.sqrt((a - c) * (a - c) + (b - d) * (b - d))

# %% [markdown]
# ## 1. Исходное изображение.

# %%
image_srs= cv2.imread('2.png', 0)

# %% [markdown]
# ## 2. Спектр изображения

# %%
image_spectrum = get_spectrum(image_srs)

# %%
image_spectrum.min()
# Out:
# -0.15922686

# %% [markdown]
# # Исходное изображение и его спектр(log)

# %%
np.log(image_spectrum)
# Out:
# C:\Temp/ipykernel_3084/1886595431.py:1: RuntimeWarning: invalid value encountered in log
#   np.log(image_spectrum)
# array([[1.3572109, 1.2184249, 1.6367278, ..., 1.5459621, 1.4557811,
#         1.6231776],
#        [1.6629176, 1.4296945, 1.4258381, ..., 1.6136774, 1.6176282,
#         1.4760911],
#        [1.4283775, 1.1910226, 1.5382855, ..., 1.5647895, 1.7264566,
#         1.5395653],
#        ...,
#        [1.5395653, 1.7264566, 1.5647895, ..., 1.5382855, 1.1910226,
#         1.4283775],
#        [1.4760911, 1.6176282, 1.6136774, ..., 1.4258381, 1.4296945,
#         1.6629176],
#        [1.6231776, 1.4557811, 1.5459621, ..., 1.6367278, 1.2184249,
#         1.3572109]], dtype=float32)

# %%
showImage([image_srs, np.log(image_spectrum)])
# Out:
# C:\Temp/ipykernel_3084/282783661.py:1: RuntimeWarning: invalid value encountered in log
#   showImage([image_srs, np.log(image_spectrum)])

# %% [markdown]
# ## 3. Идеальный фильтр

# %%
width, height = image_srs.shape
mask_I = np.zeros((width, height,2))

d = 25

dft_shift = get_fftshift(image_srs)

for i in range(width):
    for j in range(height):
        distance = int(get_distance(i, j, width/2, height/2) <= d)
        mask_I[i][j][0], mask_I[i][j][1]  = distance, distance
        
showImage([cv2.magnitude(mask_I[:,:,0], mask_I[:,:,1])])

# %%
filtrated = dft_shift * mask_I

# %% [markdown]
# # Функция хз, что делает... Сделал, чтобы убрать копипаст

# %%
def get_magnitude(image: np.ndarray):
    inverse_dft = cv2.dft(image, cv2.DFT_INVERSE)   
    return cv2.magnitude(inverse_dft[:,:, 0], inverse_dft[:,:, 1])

# %%
inverse_dft = cv2.dft(filtrated, cv2.DFT_INVERSE)
inverse_dft_magnitude = get_magnitude(filtrated)
showImage([inverse_dft_magnitude])

# %%
mask_I_rev = 1 - mask_I
showImage([cv2.magnitude(mask_I_rev[:,:,0], mask_I_rev[:,:,1])])

# %%
filtrated_I_rev = dft_shift * mask_I_rev

# %%
inverse_dft_magnitude = get_magnitude(filtrated_I_rev)
showImage([inverse_dft_magnitude])

# %%
dft_shift_I_rev = get_fftshift(inverse_dft_magnitude)
spectrum_I_rev = get_spectrum(dft_shift_I_rev)
showImage([np.log(spectrum_I_rev), np.log(get_spectrum(image_srs))])
# Out:
# C:\Temp/ipykernel_1876/3259419583.py:3: RuntimeWarning: invalid value encountered in log
#   showImage([np.log(spectrum_I_rev), np.log(get_spectrum(image_srs))])

# %%
# Батерворт
width, height = image_srs.shape
mask_B = np.zeros((width, height ,2))
d = 30 
degree = 2 * 2

for i in range(width):
    for j in range(height):
        value = 1 / (1 + (get_distance(i, j, width/2, height/2) / d) ** degree)
        mask_B[i][j][0], mask_B[i][j][1] = value, value
        
filtrated_B = dft_shift * mask_B

showImage([cv2.magnitude(mask_B[:,:,0], mask_B[:,:,1])])

# %%
inverse_dft_magnitude = get_magnitude(filtrated_B)
showImage([inverse_dft_magnitude])

# %%
# не так отрабатывает
dft_shift_B = get_fftshift(inverse_dft_magnitude)
spectrum_B = get_spectrum(dft_shift_B)
showImage([np.log(spectrum_B)])

# %%
mask_B_rev = np.zeros((m, n, 2))
d = 15
n_pow = 2

for i in range(m):
    for j in range(n):
        mask_B_rev[i][j][0] = 1 / (1 + (d / dist(i, j, m/2, n/2) / d) ** (2*n_pow))
        mask_B_rev[i][j][1] = 1 / (1 + (d / dist(i, j, m/2, n/2) / d) ** (2*n_pow))
        
filtrated_B_rev = dft_shift * mask_B_rev

imshow(cv.magnitude(mask_B_rev[:,:,0], mask_B_rev[:,:,1]))

# %%
idft = cv.dft(filtrated_B_rev, cv.DFT_INVERSE)

idft_real = idft[:,:, 0]
idft_imaginary = idft[:,:, 1]

idft_magnitude = cv.magnitude(idft_real, idft_imaginary)
plt.imshow(idft_magnitude, cmap = 'gray')

# %%
# Гаусов
mask_G = np.zeros((m, n ,2))
d = 20 

for i in range(m):
    for j in range(n):
        mask_G[i][j][0] = math.exp((-1)*(dist(i, j, m/2, n/2) ** 2) / (2*d*d))
        mask_G[i][j][1] = math.exp((-1)*(dist(i, j, m/2, n/2) ** 2) / (2*d*d))
        
filtrated_G = dft_shift * mask_G

imshow(cv.magnitude(mask_G[:,:,0], mask_G[:,:,1]))

# %%
idft = cv.dft(filtrated_G, cv.DFT_INVERSE)

idft_real = idft[:,:, 0]
idft_imaginary = idft[:,:, 1]

idft_magnitude = cv.magnitude(idft_real, idft_imaginary)
plt.imshow(idft_magnitude, cmap = 'gray')

# %%
idft
# Out:
# array([[[-1.59056565e+05,  5.83196624e+07],
#         [ 2.05901825e+05, -5.86344832e+07],
#         [-2.38310865e+05,  5.89009713e+07],
#         ...,
#         [-2.56844118e+04, -5.72355204e+07],
#         [-3.80082891e+04,  5.76034090e+07],
#         [ 1.01458520e+05, -5.79705675e+07]],
#
#        [[ 6.06613833e+05, -5.81733437e+07],
#         [-6.43214999e+05,  5.85125789e+07],
#         [ 6.61870124e+05, -5.88038980e+07],
#         ...,
#         [-4.28895011e+05,  5.70243640e+07],
#         [ 4.94346585e+05, -5.74116027e+07],
#         [-5.55426178e+05,  5.78007085e+07]],
#
#        [[-1.03312450e+06,  5.79902730e+07],
#         [ 1.05851058e+06, -5.83514190e+07],
#         [-1.06304715e+06,  5.86640042e+07],
#         ...,
#         [ 8.68376144e+05, -5.67760817e+07],
#         [-9.33192257e+05,  5.71841919e+07],
#         [ 9.89881865e+05, -5.75953543e+07]],
#
#        ...,
#
#        [[-1.21325568e+06, -5.85255487e+07],
#         [ 1.15234516e+06,  5.87752241e+07],
# ...

# %%
# не так отрабатывает
dft_shift_G = get_dft_shifted(idft)
spectrum_G = get_spectrum(dft_shift_G)
imshow(np.log(spectrum_G + 0.001))

# %%
mask_G_rev = 1 - mask_G
filtrated_G_rev = dft_shift * mask_G_rev
imshow(cv.magnitude(mask_G_rev[:,:,0], mask_G_rev[:,:,1]))

# %%
idft = cv.dft(filtrated_G_rev, cv.DFT_INVERSE)

idft_real = idft[:,:,0]
idft_imaginary = idft[:,:,0]

idft = cv.magnitude(idft_real, idft_imaginary)
plt.imshow(idft, cmap='gray')

# %%
dft_shift_G_rev = get_dft_shifted(idft)
spectrum_G_rev = get_spectrum(dft_shift_G_rev)
imshow(np.log(spectrum_G_rev))
